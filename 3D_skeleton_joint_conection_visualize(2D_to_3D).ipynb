# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\user\miniconda3\envs\frankmocap\lib\site-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in c:\users\user\miniconda3\envs\frankmocap\lib\site-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\miniconda3\envs\frankmocap\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\user\miniconda3\envs\frankmocap\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\miniconda3\envs\frankmocap\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 

pickle_f = pd.read_pickle('00000_prediction_result.pkl')
pickle_f['pred_output_list'][0]['pred_joints_img'].shape
# Out:
# (49, 3)

# %%
## joint conection 참고 : https://github.com/mkocabas/VIBE/blob/master/lib/data_utils/kp_utils.py#L212

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
#pickle_f = pd.read_pickle('00081_prediction_result.pkl')
pickle_f = pd.read_pickle('00000_prediction_result.pkl')
fig = plt.figure()
ax=fig.add_subplot(projection='3d')
clist = ['b','g','g','g','g','g','g','g','r','r','r','r','r','r','r','b','b','b','b','r','r','r','r','r','r','r','r','r','r','r','r','g','g','g','g','g','g','g','b','r','g','g','b','b','b','b','b','b','b']
for i,data in enumerate(pickle_f['pred_output_list'][0]['pred_joints_img']):
    ax.scatter(xs=data[0],ys=data[1],zs=0,zdir='y',s=5, c=clist[i])
R_array = np.array([[0 , 1],[1 , 2],[2 , 3],[3 , 4],[1 , 5],[5 , 6],[6 , 7],[1 , 8],[8 , 9],[9 ,10],[10,11],[8 ,12],[12,13],[13,14],[0 ,15],[0 ,16],[15,17],[16,18],[21,19],[19,20],[14,21],[11,24],[24,22],[22,23],[0 ,38],])
print(R_array.shape)
for r_list in R_array:
    a = r_list[0]
    b = r_list[1]
    aplk = pickle_f['pred_output_list'][0]['pred_joints_img'][a]
    bplk = pickle_f['pred_output_list'][0]['pred_joints_img'][b]
    ax.plot([aplk[0],bplk[0]],[aplk[1],bplk[1]],zs=0,zdir='y',c = 'y')
ax.axis('auto')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_xlim(750,1250)
ax.set_ylim(-1, 1)
ax.set_zlim(800,300)
ax.view_init(elev=20., azim=-80)
plt.show()
# Out:
# (25, 2)

# %%
pickle_f['pred_output_list'][0]['pred_joints_img'][0]
# Out:
# array([1018.0489  ,  361.90436 ,   18.372128], dtype=float32)
